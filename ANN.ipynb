# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)
df['label'] = dataset.target

# %%
x = df.drop('label', axis = 1)
y = df['label']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten

model = Sequential()
model.add(Flatten(input_shape=(30,)))
model.add(Dense(20, activation = 'relu'))
model.add(Dense(2, activation = 'sigmoid'))
# Out:
# C:\Users\IAST352\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist = model.fit(x_train, y_train, validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.3894 - loss: 54.6008 - val_accuracy: 0.3696 - val_loss: 28.0304
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3790 - loss: 33.9739 - val_accuracy: 0.3913 - val_loss: 22.0002
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3556 - loss: 21.6780 - val_accuracy: 0.4348 - val_loss: 14.8520
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4536 - loss: 15.0781 - val_accuracy: 0.5435 - val_loss: 8.5907
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5310 - loss: 10.1079 - val_accuracy: 0.7391 - val_loss: 4.5782
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6649 - loss: 5.9153 - val_accuracy: 0.7391 - val_loss: 3.0804
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6672 - loss: 5.0399 - val_accuracy: 0.8478 - val_loss: 2.2560
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7391 - loss: 3.6305 - val_accuracy: 0.8478 - val_loss: 1.9531
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7795 - loss: 3.0334 - val_accuracy: 0.8478 - val_loss: 1.8040
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7781 - loss: 2.4404 - val_accuracy: 0.8478 - val_loss: 1.6307

# %%
import matplotlib.pyplot as plt

#Plotting
plt.plot(hist.history['accuracy'], label='Train')
plt.plot(hist.history['val_accuracy'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(hist.history['loss'], label='Train')
plt.plot(hist.history['val_loss'], label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print('Accuracy:', hist.history['accuracy'][-1])
# Out:
# Accuracy: 0.8068459630012512
